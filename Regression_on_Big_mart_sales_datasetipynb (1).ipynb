# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df= pd.read_csv('/content/Train.csv')
df.head(8)
# Out:
#   Item_Identifier  Item_Weight Item_Fat_Content  Item_Visibility  \
# 0           FDA15        9.300          Low Fat         0.016047
# 1           DRC01        5.920          Regular         0.019278
# 2           FDN15       17.500          Low Fat         0.016760
# 3           FDX07       19.200          Regular         0.000000
# 4           NCD19        8.930          Low Fat         0.000000
# 5           FDP36       10.395          Regular         0.000000
# 6           FDO10       13.650          Regular         0.012741
# 7           FDP10          NaN          Low Fat         0.127470
#
#                Item_Type  Item_MRP Outlet_Identifier  \
# 0                  Dairy  249.8092            OUT049
# 1            Soft Drinks   48.2692            OUT018
# 2                   Meat  141.6180            OUT049
# 3  Fruits and Vegetables  182.0950            OUT010
# 4              Household   53.8614            OUT013
# 5           Baking Goods   51.4008            OUT018
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8523 entries, 0 to 8522
# Data columns (total 12 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   Item_Identifier            8523 non-null   object
#  1   Item_Weight                7060 non-null   float64
#  2   Item_Fat_Content           8523 non-null   object
#  3   Item_Visibility            8523 non-null   float64
#  4   Item_Type                  8523 non-null   object
#  5   Item_MRP                   8523 non-null   float64
#  6   Outlet_Identifier          8523 non-null   object
#  7   Outlet_Establishment_Year  8523 non-null   int64
#  8   Outlet_Size                6113 non-null   object
#  9   Outlet_Location_Type       8523 non-null   object
#  10  Outlet_Type                8523 non-null   object
#  11  Item_Outlet_Sales          8523 non-null   float64
# dtypes: float64(4), int64(1), object(7)
# memory usage: 799.2+ KB

# %%
df.describe()
# Out:
#        Item_Weight  Item_Visibility     Item_MRP  Outlet_Establishment_Year  \
# count  7060.000000      8523.000000  8523.000000                8523.000000
# mean     12.857645         0.066132   140.992782                1997.831867
# std       4.643456         0.051598    62.275067                   8.371760
# min       4.555000         0.000000    31.290000                1985.000000
# 25%       8.773750         0.026989    93.826500                1987.000000
# 50%      12.600000         0.053931   143.012800                1999.000000
# 75%      16.850000         0.094585   185.643700                2004.000000
# max      21.350000         0.328391   266.888400                2009.000000
#
#        Item_Outlet_Sales
# count        8523.000000
# mean         2181.288914
# std          1706.499616
# min            33.290000
# 25%           834.247400
# 50%          1794.331000
# 75%          3101.296400
# max         13086.964800

# %%
df['Item_Identifier'].value_counts()
# Out:
# FDW13    10
# FDG33    10
# NCY18     9
# FDD38     9
# DRE49     9
#          ..
# FDY43     1
# FDQ60     1
# FDO33     1
# DRF48     1
# FDC23     1
# Name: Item_Identifier, Length: 1559, dtype: int64

# %%
df['Item_Fat_Content'].value_counts()
# Out:
# Low Fat    5089
# Regular    2889
# LF          316
# reg         117
# low fat     112
# Name: Item_Fat_Content, dtype: int64

# %%
df['Item_Type'].value_counts()
# Out:
# Fruits and Vegetables    1232
# Snack Foods              1200
# Household                 910
# Frozen Foods              856
# Dairy                     682
# Canned                    649
# Baking Goods              648
# Health and Hygiene        520
# Soft Drinks               445
# Meat                      425
# Breads                    251
# Hard Drinks               214
# Others                    169
# Starchy Foods             148
# Breakfast                 110
# Seafood                    64
# Name: Item_Type, dtype: int64

# %%
df['Outlet_Identifier'].value_counts()
# Out:
# OUT027    935
# OUT013    932
# OUT049    930
# OUT046    930
# OUT035    930
# OUT045    929
# OUT018    928
# OUT017    926
# OUT010    555
# OUT019    528
# Name: Outlet_Identifier, dtype: int64

# %%
df['Outlet_Size'].value_counts()
# Out:
# Medium    2793
# Small     2388
# High       932
# Name: Outlet_Size, dtype: int64

# %%
df['Outlet_Location_Type'].value_counts()
# Out:
# Tier 3    3350
# Tier 2    2785
# Tier 1    2388
# Name: Outlet_Location_Type, dtype: int64

# %%
df['Outlet_Type'].value_counts()
# Out:
# Supermarket Type1    5577
# Grocery Store        1083
# Supermarket Type3     935
# Supermarket Type2     928
# Name: Outlet_Type, dtype: int64

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8523 entries, 0 to 8522
# Data columns (total 12 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   Item_Identifier            8523 non-null   object
#  1   Item_Weight                7060 non-null   float64
#  2   Item_Fat_Content           8523 non-null   object
#  3   Item_Visibility            8523 non-null   float64
#  4   Item_Type                  8523 non-null   object
#  5   Item_MRP                   8523 non-null   float64
#  6   Outlet_Identifier          8523 non-null   object
#  7   Outlet_Establishment_Year  8523 non-null   int64
#  8   Outlet_Size                6113 non-null   object
#  9   Outlet_Location_Type       8523 non-null   object
#  10  Outlet_Type                8523 non-null   object
#  11  Item_Outlet_Sales          8523 non-null   float64
# dtypes: float64(4), int64(1), object(7)
# memory usage: 799.2+ KB

# %%
df.drop('Item_Identifier',axis=1,inplace=True)
df.head(5)
# Out:
#    Item_Weight Item_Fat_Content  Item_Visibility              Item_Type  \
# 0         9.30          Low Fat         0.016047                  Dairy
# 1         5.92          Regular         0.019278            Soft Drinks
# 2        17.50          Low Fat         0.016760                   Meat
# 3        19.20          Regular         0.000000  Fruits and Vegetables
# 4         8.93          Low Fat         0.000000              Household
#
#    Item_MRP Outlet_Identifier  Outlet_Establishment_Year Outlet_Size  \
# 0  249.8092            OUT049                       1999      Medium
# 1   48.2692            OUT018                       2009      Medium
# 2  141.6180            OUT049                       1999      Medium
# 3  182.0950            OUT010                       1998         NaN
# 4   53.8614            OUT013                       1987        High
#
#   Outlet_Location_Type        Outlet_Type  Item_Outlet_Sales
# ...

# %%
df['Outlet_Size'].tail(5)
# Out:
# 8518      High
# 8519       NaN
# 8520     Small
# 8521    Medium
# 8522     Small
# Name: Outlet_Size, dtype: object

# %%
df['Item_Weight']=df['Item_Weight'].fillna(df['Item_Weight'].median())
df['Outlet_Size']=df['Outlet_Size'].fillna(method="ffill")
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8523 entries, 0 to 8522
# Data columns (total 11 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   Item_Weight                8523 non-null   float64
#  1   Item_Fat_Content           8523 non-null   object
#  2   Item_Visibility            8523 non-null   float64
#  3   Item_Type                  8523 non-null   object
#  4   Item_MRP                   8523 non-null   float64
#  5   Outlet_Identifier          8523 non-null   object
#  6   Outlet_Establishment_Year  8523 non-null   int64
#  7   Outlet_Size                8523 non-null   object
#  8   Outlet_Location_Type       8523 non-null   object
#  9   Outlet_Type                8523 non-null   object
#  10  Item_Outlet_Sales          8523 non-null   float64
# dtypes: float64(4), int64(1), object(6)
# memory usage: 732.6+ KB

# %%
df.describe()
# Out:
#        Item_Weight  Item_Visibility     Item_MRP  Outlet_Establishment_Year  \
# count   8523.00000      8523.000000  8523.000000                8523.000000
# mean      12.81342         0.066132   140.992782                1997.831867
# std        4.22724         0.051598    62.275067                   8.371760
# min        4.55500         0.000000    31.290000                1985.000000
# 25%        9.31000         0.026989    93.826500                1987.000000
# 50%       12.60000         0.053931   143.012800                1999.000000
# 75%       16.00000         0.094585   185.643700                2004.000000
# max       21.35000         0.328391   266.888400                2009.000000
#
#        Item_Outlet_Sales
# count        8523.000000
# mean         2181.288914
# std          1706.499616
# min            33.290000
# 25%           834.247400
# 50%          1794.331000
# 75%          3101.296400
# max         13086.964800

# %%
sns.set()

# %%
df[['Item_Weight','Item_MRP']].boxplot()
# Out:
# <Axes: >

# %%
df[['Item_Visibility']].boxplot()
# Out:
# <Axes: >

# %%
df[df['Item_Visibility']>=0.20]
# Out:
#       Item_Weight Item_Fat_Content  Item_Visibility              Item_Type  \
# 49          12.60          Regular         0.255395                  Dairy
# 83          12.60          Low Fat         0.293418              Household
# 108         12.60          low fat         0.278974            Soft Drinks
# 174         17.70          Low Fat         0.291865  Fruits and Vegetables
# 334         12.60          Low Fat         0.204700           Frozen Foods
# ...           ...              ...              ...                    ...
# 8292        12.60          Regular         0.209163  Fruits and Vegetables
# 8345        12.60          Regular         0.266397           Frozen Foods
# 8371         8.27          Regular         0.214125            Soft Drinks
# 8432        14.00          Regular         0.227261           Frozen Foods
# 8509         8.10          Low Fat         0.214306  Fruits and Vegetables
#
# ...

# %%
df.drop(df[df['Item_Visibility']>=0.20].index,inplace=True)
df[df['Item_Visibility']>=0.20]
# Out:
# Empty DataFrame
# Columns: [Item_Weight, Item_Fat_Content, Item_Visibility, Item_Type, Item_MRP, Outlet_Identifier, Outlet_Establishment_Year, Outlet_Size, Outlet_Location_Type, Outlet_Type, Item_Outlet_Sales]
# Index: []

# %%
df[['Outlet_Establishment_Year','Item_Outlet_Sales']].boxplot()
# Out:
# <Axes: >

# %%
df[df['Item_Outlet_Sales']>=6000]
# Out:
#       Item_Weight Item_Fat_Content  Item_Visibility           Item_Type  \
# 43         21.350          Low Fat         0.069103              Canned
# 55          7.905          Low Fat         0.010053         Snack Foods
# 130        12.600          Low Fat         0.033810              Canned
# 132        12.600          Low Fat         0.144338  Health and Hygiene
# 145        18.600          Low Fat         0.039356        Frozen Foods
# ...           ...              ...              ...                 ...
# 8329       12.600          Low Fat         0.041622           Household
# 8350       10.000          Low Fat         0.021421           Household
# 8447       20.350          Low Fat         0.089975               Dairy
# 8485       12.600          Low Fat         0.043792         Soft Drinks
# 8510       13.800          Regular         0.056862         Snack Foods
#
#       Item_MRP Outlet_Identifier  Outlet_Establishment_Year Outlet_Size  \
# ...

# %%
df.drop(df[df['Item_Outlet_Sales']>=6200].index,inplace=True)
df[['Item_Outlet_Sales']].boxplot()
# Out:
# <Axes: >

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 8151 entries, 0 to 8522
# Data columns (total 11 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   Item_Weight                8151 non-null   float64
#  1   Item_Fat_Content           8151 non-null   object
#  2   Item_Visibility            8151 non-null   float64
#  3   Item_Type                  8151 non-null   object
#  4   Item_MRP                   8151 non-null   float64
#  5   Outlet_Identifier          8151 non-null   object
#  6   Outlet_Establishment_Year  8151 non-null   int64
#  7   Outlet_Size                8151 non-null   object
#  8   Outlet_Location_Type       8151 non-null   object
#  9   Outlet_Type                8151 non-null   object
#  10  Item_Outlet_Sales          8151 non-null   float64
# dtypes: float64(4), int64(1), object(6)
# memory usage: 764.2+ KB

# %%
from sklearn.preprocessing import LabelEncoder

# %%
encoder= LabelEncoder()

# %%
df['Item_Fat_Content']=encoder.fit_transform(df['Item_Fat_Content'])
df['Item_Fat_Content']
# Out:
# 0       1
# 1       2
# 2       1
# 3       2
# 4       1
#        ..
# 8518    1
# 8519    2
# 8520    1
# 8521    2
# 8522    1
# Name: Item_Fat_Content, Length: 8151, dtype: int64

# %%
df['Item_Type']=encoder.fit_transform(df['Item_Type'])
df['Outlet_Identifier']=encoder.fit_transform(df['Outlet_Identifier'])
df['Outlet_Size']=encoder.fit_transform(df['Outlet_Size'])
df['Outlet_Location_Type']=encoder.fit_transform(df['Outlet_Location_Type'])
df['Outlet_Type']=encoder.fit_transform(df['Outlet_Type'])
df.head(10)
# Out:
#    Item_Weight  Item_Fat_Content  Item_Visibility  Item_Type  Item_MRP  \
# 0        9.300                 1         0.016047          4  249.8092
# 1        5.920                 2         0.019278         14   48.2692
# 2       17.500                 1         0.016760         10  141.6180
# 3       19.200                 2         0.000000          6  182.0950
# 4        8.930                 1         0.000000          9   53.8614
# 5       10.395                 2         0.000000          0   51.4008
# 6       13.650                 2         0.012741         13   57.6588
# 7       12.600                 1         0.127470         13  107.7622
# 8       16.200                 2         0.016687          5   96.9726
# 9       19.200                 2         0.094450          5  187.8214
#
#    Outlet_Identifier  Outlet_Establishment_Year  Outlet_Size  \
# 0                  9                       1999            1
# 1                  3                       2009            1
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 8151 entries, 0 to 8522
# Data columns (total 11 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   Item_Weight                8151 non-null   float64
#  1   Item_Fat_Content           8151 non-null   int64
#  2   Item_Visibility            8151 non-null   float64
#  3   Item_Type                  8151 non-null   int64
#  4   Item_MRP                   8151 non-null   float64
#  5   Outlet_Identifier          8151 non-null   int64
#  6   Outlet_Establishment_Year  8151 non-null   int64
#  7   Outlet_Size                8151 non-null   int64
#  8   Outlet_Location_Type       8151 non-null   int64
#  9   Outlet_Type                8151 non-null   int64
#  10  Item_Outlet_Sales          8151 non-null   float64
# dtypes: float64(4), int64(7)
# memory usage: 764.2 KB

# %%
df1=df[['Item_Weight','Item_Fat_Content','Item_Visibility','Item_Type','Item_MRP','Item_Outlet_Sales']]
df1
# Out:
#       Item_Weight  Item_Fat_Content  Item_Visibility  Item_Type  Item_MRP  \
# 0           9.300                 1         0.016047          4  249.8092
# 1           5.920                 2         0.019278         14   48.2692
# 2          17.500                 1         0.016760         10  141.6180
# 3          19.200                 2         0.000000          6  182.0950
# 4           8.930                 1         0.000000          9   53.8614
# ...           ...               ...              ...        ...       ...
# 8518        6.865                 1         0.056783         13  214.5218
# 8519        8.380                 2         0.046982          0  108.1570
# 8520       10.600                 1         0.035186          8   85.1224
# 8521        7.210                 2         0.145221         13  103.1332
# 8522       14.800                 1         0.044878         14   75.4670
#
#       Item_Outlet_Sales
# 0             3735.1380
# 1              443.4228
# ...

# %%
sns.set()
sns.heatmap(df1.corr(),annot=True)
plt.show()

# %%
df2=df[['Outlet_Identifier','Outlet_Establishment_Year','Outlet_Size','Outlet_Location_Type','Outlet_Type','Item_Outlet_Sales']]
df2
sns.set()
sns.heatmap(df2.corr(),annot=True)
plt.show()

# %%
from sklearn.linear_model import LinearRegression
from sklearn.preprocessing import StandardScaler
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import PolynomialFeatures

# %%
X = pd.DataFrame(df.iloc[:, :-1])
X
# Out:
#       Item_Weight  Item_Fat_Content  Item_Visibility  Item_Type  Item_MRP  \
# 0           9.300                 1         0.016047          4  249.8092
# 1           5.920                 2         0.019278         14   48.2692
# 2          17.500                 1         0.016760         10  141.6180
# 3          19.200                 2         0.000000          6  182.0950
# 4           8.930                 1         0.000000          9   53.8614
# ...           ...               ...              ...        ...       ...
# 8518        6.865                 1         0.056783         13  214.5218
# 8519        8.380                 2         0.046982          0  108.1570
# 8520       10.600                 1         0.035186          8   85.1224
# 8521        7.210                 2         0.145221         13  103.1332
# 8522       14.800                 1         0.044878         14   75.4670
#
#       Outlet_Identifier  Outlet_Establishment_Year  Outlet_Size  \
# ...

# %%
Y= df['Item_Outlet_Sales']
Y
# Out:
# 0       3735.1380
# 1        443.4228
# 2       2097.2700
# 3        732.3800
# 4        994.7052
#           ...
# 8518    2778.3834
# 8519     549.2850
# 8520    1193.1136
# 8521    1845.5976
# 8522     765.6700
# Name: Item_Outlet_Sales, Length: 8151, dtype: float64

# %%
poly=PolynomialFeatures(degree=3)

# %%
x_poly=poly.fit_transform(X)

# %%
scaler= StandardScaler()

# %%
x_poly=pd.DataFrame(scaler.fit_transform(x_poly))
x_poly
# Out:
#       0         1         2         3         4         5         6    \
# 0     0.0 -0.825721 -0.570389 -1.018092 -0.767977  1.811422  1.489755
# 1     0.0 -1.617353  0.975237 -0.948625  1.609637 -1.472467 -0.616636
# 2     0.0  1.094807 -0.570389 -1.002767  0.658591  0.048557  1.489755
# 3     0.0  1.492965  0.975237 -1.363120 -0.292454  0.708088 -1.669832
# 4     0.0 -0.912379 -0.570389 -1.363120  0.420830 -1.381348 -1.318767
# ...   ...       ...       ...       ...       ...       ...       ...
# 8146  0.0 -1.396024 -0.570389 -0.142236  1.371875  1.236450 -1.318767
# 8147  0.0 -1.041195  0.975237 -0.352964 -1.719023 -0.496656  0.787625
# 8148  0.0 -0.521247 -0.570389 -0.606590  0.183068 -0.871982  0.436560
# 8149  0.0 -1.315221  0.975237  1.759229  1.371875 -0.578514 -0.616636
# 8150  0.0  0.462438 -0.570389 -0.398205  1.609637 -1.029307  1.138690
#
#            7         8         9    ...       276       277       278  \
# ...

# %%
x_train, x_test, y_train, y_test= train_test_split(x_poly,Y,test_size=0.2,random_state=42)

# %%
regressor=LinearRegression()

# %%
regressor.fit(x_train,y_train)
# Out:
# LinearRegression()

# %%
regressor.score(x_train,y_train)
# Out:
# 0.6020723100249148

# %%
regressor.score(x_test,y_test)
# Out:
# 0.57608778404888

# %%
y_pred= regressor.predict(x_test)
y_pred
# Out:
# array([2355.83053679,  377.32272429, 2541.58834929, ..., 3716.68209929,
#        2166.71334929, 3073.45553679])

# %%
results= pd.DataFrame({'y_test':y_test,'y_pred':y_pred})
results
# Out:
#          y_test       y_pred
# 6872  1765.7016  2355.830537
# 510    774.9912   377.322724
# 7955  3124.5994  2541.588349
# 4117   234.3616    89.041474
# 7397  2587.9646  2774.994599
# ...         ...          ...
# 5285   222.3772   184.635224
# 2994  3079.9908  2784.338349
# 309   3038.0454  3716.682099
# 6231  1685.8056  2166.713349
# 3959  3203.1638  3073.455537
#
# [1631 rows x 2 columns]

# %%
from sklearn.metrics import mean_squared_error

# %%
mse= mean_squared_error(y_test,y_pred)
rmse= np.sqrt(mse)
rmse
# Out:
# 962.7610374996585

# %% [markdown]
# **2nd model**

# %%
x2= df[['Item_MRP','Outlet_Type']]
x2
# Out:
#       Item_MRP  Outlet_Type
# 0     249.8092            1
# 1      48.2692            2
# 2     141.6180            1
# 3     182.0950            0
# 4      53.8614            1
# ...        ...          ...
# 8518  214.5218            1
# 8519  108.1570            1
# 8520   85.1224            1
# 8521  103.1332            2
# 8522   75.4670            1
#
# [8151 rows x 2 columns]

# %%
x2_poly=poly.fit_transform(x2)

# %%
x2_poly=pd.DataFrame(scaler.fit_transform(x2_poly))
x2_poly
# Out:
#         0         1         2         3         4         5         6  \
# 0     0.0  1.811422 -0.255607  2.182506  0.649704 -0.401310  2.441408
# 1     0.0 -1.472467  1.044924 -1.143762 -0.511536  0.775618 -0.896057
# 2     0.0  0.048557 -0.255607 -0.162308 -0.169995 -0.401310 -0.307830
# 3     0.0  0.708088 -1.556137  0.563186 -1.242949 -0.793619  0.381748
# 4     0.0 -1.381348 -0.255607 -1.112138 -0.834874 -0.401310 -0.886614
# ...   ...       ...       ...       ...       ...       ...       ...
# 8146  0.0  1.236450 -0.255607  1.275286  0.382353 -0.401310  1.208566
# 8147  0.0 -0.496656 -0.255607 -0.625065 -0.423509 -0.401310 -0.647474
# 8148  0.0 -0.871982 -0.255607 -0.871573 -0.598028 -0.401310 -0.787304
# 8149  0.0 -0.578514  1.044924 -0.683838  0.319807  0.775618 -0.683755
# 8150  0.0 -1.029307 -0.255607 -0.957426 -0.671181 -0.401310 -0.827625
#
#              7         8         9
# 0     1.205137 -0.061805 -0.414043
# 1    -0.757217 -0.210105  0.470356
# ...

# %%
x2_train, x2_test, y2_train, y2_test= train_test_split(x2_poly,Y,test_size=0.2,random_state=42)

# %%
x2_train
# Out:
#         0         1         2         3         4         5         6  \
# 8144  0.0 -1.301550  1.044924 -1.081600 -0.352589  0.775618 -0.876561
# 6699  0.0  0.138604 -0.255607 -0.073949 -0.128125 -0.401310 -0.233293
# 4949  0.0  0.051258 -0.255607 -0.159706 -0.168739 -0.401310 -0.305676
# 7558  0.0  1.872698  1.044924  2.287320  2.599340  0.775618  2.595526
# 7680  0.0 -0.881716 -0.255607 -0.877185 -0.602554 -0.401310 -0.790085
# ...   ...       ...       ...       ...       ...       ...       ...
# 5226  0.0 -0.544854  2.345454 -0.660009  1.148138  2.737164 -0.669253
# 5390  0.0 -0.754792  1.044924 -0.800914  0.155875  0.775618 -0.750662
# 860   0.0  1.286919 -0.255607  1.349398  0.405820 -0.401310  1.302118
# 7603  0.0 -0.775417 -1.556137 -0.813765 -1.242949 -0.793619 -0.757545
# 7270  0.0 -1.552695 -0.255607 -1.168738 -0.914547 -0.401310 -0.902747
#
#              7         8         9
# 8144 -0.680913 -0.100425  0.470356
# 6699 -0.179787 -0.330173 -0.414043
# ...

# %%
regressor.fit(x2_train,y2_train)
regressor.score(x2_train,y2_train)
# Out:
# 0.5821686109784057

# %%
regressor.score(x2_test,y2_test)
# Out:
# 0.576623686192564

# %%
y2_pred= regressor.predict(x2_test)
y2_pred
# Out:
# array([2417.44155214,  574.52708849, 2680.98132512, ..., 3518.4915546 ,
#        2313.63872634, 2967.02465656])

# %%
results2= pd.DataFrame({'y_test':y2_test,'y_pred':y2_pred})
results2
# Out:
#          y_test       y_pred
# 6872  1765.7016  2417.441552
# 510    774.9912   574.527088
# 7955  3124.5994  2680.981325
# 4117   234.3616   191.572468
# 7397  2587.9646  3046.414118
# ...         ...          ...
# 5285   222.3772   163.474103
# 2994  3079.9908  2752.125732
# 309   3038.0454  3518.491555
# 6231  1685.8056  2313.638726
# 3959  3203.1638  2967.024657
#
# [1631 rows x 2 columns]

# %%
mse2= mean_squared_error(y2_test,y2_pred)
mse2
# Out:
# 925737.0339952413

# %%
rmse2= np.sqrt(mse2)
rmse2
# Out:
# 962.1522925167519

# %%
from sklearn.metrics import mean_absolute_error

# %%
mae = mean_absolute_error(y2_test,y2_pred)
mae
# Out:
# 712.766197060624

# %%
df.head()
# Out:
#    Item_Weight  Item_Fat_Content  Item_Visibility  Item_Type  Item_MRP  \
# 0         9.30                 1         0.016047          4  249.8092
# 1         5.92                 2         0.019278         14   48.2692
# 2        17.50                 1         0.016760         10  141.6180
# 3        19.20                 2         0.000000          6  182.0950
# 4         8.93                 1         0.000000          9   53.8614
#
#    Outlet_Identifier  Outlet_Establishment_Year  Outlet_Size  \
# 0                  9                       1999            1
# 1                  3                       2009            1
# 2                  9                       1999            1
# 3                  0                       1998            1
# 4                  1                       1987            0
#
#    Outlet_Location_Type  Outlet_Type  Item_Outlet_Sales
# 0                     0            1          3735.1380
# 1                     2            2           443.4228
# ...
